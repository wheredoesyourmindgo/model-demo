# %% [markdown]
# # Data Collection

# %%
import requests
import pandas as pd
import numpy as np
import urllib3
import warnings
import json
import os
from pathlib import Path
from dotenv import load_dotenv

# %%
dotenv_path = Path('.env.local')
load_dotenv(dotenv_path=dotenv_path)
EIA_API_KEY = os.getenv("EIA_API_KEY")

# %% [markdown]
# All of the requests below return data for the following date range on a daily basis, from 1/1/2018 to 8/20/2023, roughly 5.7 years of data.

# %%
# disable certificate warnings for PI Web API at 10.50.50.111
urllib3.disable_warnings()

# %% [markdown]
# ## Oxbow Flows

# %%
def NOT_SURE_get_oxbow_flows():
    # Oxbow Flows (5.7yr)
    # GET https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AGRk_MVS45BGT9wAMKbY5uQq1qO6caoSkyCSiFYjVrVZQQlVTSU5FU1NQSTJcT1BTXEdFTkVSQVRJT04gVU5JVFNcT1hCT1d8UkVMRUFTRQ/interpolated

    try:
        response = requests.get(
            url="https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AGRk_MVS45BGT9wAMKbY5uQq1qO6caoSkyCSiFYjVrVZQQlVTSU5FU1NQSTJcT1BTXEdFTkVSQVRJT04gVU5JVFNcT1hCT1d8UkVMRUFTRQ/interpolated",
            params={
                "startTime": "2018-01-01T08:00:00.000Z",
                "endTime": "2023-08-20T07:00:00.000Z",
                "interval": "1d",
            },
            verify=False
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        print('Response HTTP Response Body: {content}'.format(
            content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
def get_oxbow_flows():
    # Oxbow Flows (5.7yr)
    # GET https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AGRk_MVS45BGT9wAMKbY5uQOCXUJKCcSlwJLc1IoW7p9wQlVTSU5FU1NQSTJcT1BTXEdFTkVSQVRJT04gVU5JVFNcT1hCT1d8V0FURVIgRkxPVw/interpolated

    try:
        response = requests.get(
            url="https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AGRk_MVS45BGT9wAMKbY5uQOCXUJKCcSlwJLc1IoW7p9wQlVTSU5FU1NQSTJcT1BTXEdFTkVSQVRJT04gVU5JVFNcT1hCT1d8V0FURVIgRkxPVw/interpolated",
            params={
                "startTime": "2018-01-01T08:00:00.000Z",
                "endTime": "2023-08-20T07:00:00.000Z",
                "interval": "1d",
            },
            verify=False
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        #print('Response HTTP Response Body: {content}'.format(
        #    content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
oxbow_flows_res = get_oxbow_flows()
# Out:
# Response HTTP Status Code: 200

# %%
oxbow_flows_data = oxbow_flows_res.json()

# %%
oxbow_flows_data_mapped = oxbow_flows_data['Items']

# %%
ox_df = pd.DataFrame(oxbow_flows_data_mapped)

# %%
ox_df
# Out:
#                  Timestamp        Value UnitsAbbreviation  Good  Questionable  \
# 0     2018-01-01T08:00:00Z   272.556824               CFS  True         False
# 1     2018-01-02T08:00:00Z   253.365768               CFS  True         False
# 2     2018-01-03T08:00:00Z   672.777900               CFS  True         False
# 3     2018-01-04T08:00:00Z   574.729000               CFS  True         False
# 4     2018-01-05T08:00:00Z   533.206500               CFS  True         False
# ...                    ...          ...               ...   ...           ...
# 2053  2023-08-16T07:00:00Z  1008.626280               CFS  True         False
# 2054  2023-08-17T07:00:00Z  1012.407470               CFS  True         False
# 2055  2023-08-18T07:00:00Z  1001.064000               CFS  True         False
# 2056  2023-08-19T07:00:00Z  1004.845150               CFS  True         False
# 2057  2023-08-20T07:00:00Z  1012.407470               CFS  True         False
#
#       Substituted  Annotated
# 0           False      False
# 1           False      False
# 2           False      False
# 3           False      False
# 4           False      False
# ...           ...        ...
# 2053        False      False
# 2054        False      False
# 2055        False      False
# 2056        False      False
# 2057        False      False
#
# [2058 rows x 7 columns]

# %%
ox_df.to_csv('./data/oxbow_flows.csv', index_label='Index')

# %% [markdown]
# ## French Meadows Storage

# %%
def get_french_meadows_storage():
    # French Meadow Storage (5.7yr)
    # GET https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AJRk_MVS45BGT9wAMKbY5uQQHGf-gS9WlQUY0roQOBJbQQlVTSU5FU1NQSTJcT1BTXFJFU0VSVk9JUlNcRlJFTkNIIE1FQURPV1N8U1RPUkFHRQ/interpolated

    try:
        response = requests.get(
            url="https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AJRk_MVS45BGT9wAMKbY5uQQHGf-gS9WlQUY0roQOBJbQQlVTSU5FU1NQSTJcT1BTXFJFU0VSVk9JUlNcRlJFTkNIIE1FQURPV1N8U1RPUkFHRQ/interpolated",
            params={
                "startTime": "2018-01-01T08:00:00.000Z",
                "endTime": "2023-08-20T07:00:00.000Z",
                "interval": "1d",
            },
            verify=False
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        print('Response HTTP Response Body: {content}'.format(
            content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
french_meadows_storage_res = get_french_meadows_storage()
# Out:
# Response HTTP Status Code: 200
# Response HTTP Response Body: b'{"Links":{},"Items":[{"Timestamp":"2018-01-01T08:00:00Z","Value":51445.0,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-02T08:00:00Z","Value":51391.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-03T08:00:00Z","Value":51391.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-04T08:00:00Z","Value":51270.5,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-05T08:00:00Z","Value":51391.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-06T08:00:00Z","Value":51391.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-07T08:00:00Z","Value":52289.1,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-08T08:00:00Z","Value":52543.2,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-09T08:00:00Z","Value":53062.2,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-10T08:00:00Z","Value":54486.9,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-11T08:00:00Z","Value":55534.2,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-12T08:00:00Z","Value":56066.3,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-13T08:00:00Z","Value":56464.9,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-14T08:00:00Z","Value":56728.5,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-15T08:00:00Z","Value":56865.0,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-16T08:00:00Z","Value":56865.0,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-17T08:00:00Z","Value":56992.7,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-18T08:00:00Z","Value":56992.7,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-19T08:00:00Z","Value":56992.7,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-20T08:00:00Z","Value":57266.7,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-21T08:00:00Z","Value":57394.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-22T08:00:00Z","Value":57394.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-23T08:00:00Z","Value":57266.7,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-24T08:00:00Z","Value":57266.7,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-25T08:00:00Z","Value":57394.8,"UnitsAbbreviation":"acre ft","Good":true,"Questionable":false,"Substituted":false,"Annotated":false},{"Timestamp":"2018-01-26T08:00:00Z","Value":57532.2,"UnitsAbbreviation":"acre ft","Good":true,"Que ...

# %%
french_meadows_storage_data = french_meadows_storage_res.json()

# %%
french_meadows_storage_data_mapped = french_meadows_storage_data['Items']

# %%
fm_df = pd.DataFrame(french_meadows_storage_data_mapped)

# %%
fm_df
# Out:
#                  Timestamp     Value UnitsAbbreviation  Good  Questionable  \
# 0     2018-01-01T08:00:00Z   51445.0           acre ft  True         False
# 1     2018-01-02T08:00:00Z   51391.8           acre ft  True         False
# 2     2018-01-03T08:00:00Z   51391.8           acre ft  True         False
# 3     2018-01-04T08:00:00Z   51270.5           acre ft  True         False
# 4     2018-01-05T08:00:00Z   51391.8           acre ft  True         False
# ...                    ...       ...               ...   ...           ...
# 2053  2023-08-16T07:00:00Z  105520.0           acre ft  True         False
# 2054  2023-08-17T07:00:00Z  105054.4           acre ft  True         False
# 2055  2023-08-18T07:00:00Z  105017.7           acre ft  True         False
# 2056  2023-08-19T07:00:00Z  104993.2           acre ft  True         False
# 2057  2023-08-20T07:00:00Z  104956.5           acre ft  True         False
#
#       Substituted  Annotated
# 0           False      False
# 1           False      False
# 2           False      False
# 3           False      False
# 4           False      False
# ...           ...        ...
# 2053        False      False
# 2054        False      False
# 2055        False      False
# 2056        False      False
# 2057        False      False
#
# [2058 rows x 7 columns]

# %%
fm_df.to_csv('./data/french_meadows_storage.csv', index_label='Index')

# %% [markdown]
# ## Hell Hole Storage

# %%
def get_hell_hole_storage():
    # Hell Hole Storage (5.7yr)
    # GET https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AKBk_MVS45BGT9wAMKbY5uQTXGf-gS9WlQUY0roQOBJbQQlVTSU5FU1NQSTJcT1BTXFJFU0VSVk9JUlNcSEVMTCBIT0xFfFNUT1JBR0U/interpolated

    try:
        response = requests.get(
            url="https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AKBk_MVS45BGT9wAMKbY5uQTXGf-gS9WlQUY0roQOBJbQQlVTSU5FU1NQSTJcT1BTXFJFU0VSVk9JUlNcSEVMTCBIT0xFfFNUT1JBR0U/interpolated",
            params={
                "startTime": "2018-01-01T08:00:00.000Z",
                "endTime": "2023-08-20T07:00:00.000Z",
                "interval": "1d",
            },
            verify=False
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        #print('Response HTTP Response Body: {content}'.format(
        #    content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
hell_hole_storage_res = get_hell_hole_storage()
# Out:
# Response HTTP Status Code: 200

# %%
hell_hole_storage_data = hell_hole_storage_res.json()

# %%
hell_hole_storage_data_mapped = hell_hole_storage_data['Items']

# %%
hh_df = pd.DataFrame(hell_hole_storage_data_mapped)

# %%
hh_df
# Out:
#                  Timestamp     Value UnitsAbbreviation  Good  Questionable  \
# 0     2018-01-01T08:00:00Z  109262.4           acre ft  True         False
# 1     2018-01-02T08:00:00Z  108832.6           acre ft  True         False
# 2     2018-01-03T08:00:00Z  107713.5           acre ft  True         False
# 3     2018-01-04T08:00:00Z  106513.1           acre ft  True         False
# 4     2018-01-05T08:00:00Z  105620.7           acre ft  True         False
# ...                    ...       ...               ...   ...           ...
# 2053  2023-08-16T07:00:00Z  164534.8           acre ft  True         False
# 2054  2023-08-17T07:00:00Z  163274.8           acre ft  True         False
# 2055  2023-08-18T07:00:00Z  161453.6           acre ft  True         False
# 2056  2023-08-19T07:00:00Z  159639.9           acre ft  True         False
# 2057  2023-08-20T07:00:00Z  157820.3           acre ft  True         False
#
#       Substituted  Annotated
# 0           False      False
# 1           False      False
# 2           False      False
# 3           False      False
# 4           False      False
# ...           ...        ...
# 2053        False      False
# 2054        False      False
# 2055        False      False
# 2056        False      False
# 2057        False      False
#
# [2058 rows x 7 columns]

# %%
hh_df.to_csv('./data/hell_hole_storage.csv', index_label='Index')

# %%
# enable certificate warnings for other APIs
warnings.resetwarnings()

# %% [markdown]
# ## Oxbow Power

# %%
def get_oxbow_power():
    # Oxbow Power (5.7yr)
    # GET https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AGRk_MVS45BGT9wAMKbY5uQ0zssfH8i4V4nRvraH27J9gQlVTSU5FU1NQSTJcT1BTXEdFTkVSQVRJT04gVU5JVFNcT1hCT1d8UE9XRVI/interpolated

    try:
        response = requests.get(
            url="https://10.50.50.111/piwebapi/streams/F1AbEvXCmerKddk-VtN6YtBmF5AGRk_MVS45BGT9wAMKbY5uQ0zssfH8i4V4nRvraH27J9gQlVTSU5FU1NQSTJcT1BTXEdFTkVSQVRJT04gVU5JVFNcT1hCT1d8UE9XRVI/interpolated",
            params={
                "startTime": "2018-01-01T08:00:00.000Z",
                "endTime": "2023-08-20T07:00:00.000Z",
                "interval": "1d",
            },
            verify=False
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        #print('Response HTTP Response Body: {content}'.format(
        #    content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
oxbow_power_res = get_oxbow_power()
# Out:
# Response HTTP Status Code: 200

# %%
oxbow_power_data = oxbow_power_res.json()

# %%
oxbow_power_data_mapped = oxbow_power_data['Items']

# %%
ox_pwr_df = pd.DataFrame(oxbow_power_data_mapped)

# %%
ox_pwr_df.head()
# Out:
#               Timestamp     Value UnitsAbbreviation  Good  Questionable  \
# 0  2018-01-01T08:00:00Z  2.892164                MW  True         False
# 1  2018-01-02T08:00:00Z  3.767556                MW  True         False
# 2  2018-01-03T08:00:00Z  3.134460                MW  True         False
# 3  2018-01-04T08:00:00Z  5.768452                MW  True         False
# 4  2018-01-05T08:00:00Z  3.728476                MW  True         False
#
#    Substituted  Annotated
# 0        False      False
# 1        False      False
# 2        False      False
# 3        False      False
# 4        False      False

# %%
ox_pwr_df.to_csv('./data/oxbow_power.csv', index_label='Index')

# %% [markdown]
# ## U.S. Energy Information Administration (EIA)

# %% [markdown]
# ### Natural Gas Price (NYMEX @ Henry Hub)

# %%
def get_ntrl_gas_price():
    # Natural Gas
    # GET https://api.eia.gov/v2/natural-gas/pri/fut/data/

    try:
        response = requests.get(
            url="https://api.eia.gov/v2/natural-gas/pri/fut/data/",
            params={
                "frequency": "daily",
                "data[0]": "value",
                "facets[process][]": "PS0",
                "start": "2018-01-01",
                "end": "2023-08-20",
                "sort[0][column]": "period",
                "sort[0][direction]": "desc",
                "offset": "0",
                "length": "5000",
                "api_key": EIA_API_KEY,
            },
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        #print('Response HTTP Response Body: {content}'.format(
        #    content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
ntrl_gas_price_res = get_ntrl_gas_price()
# Out:
# Response HTTP Status Code: 403

# %%
ntrl_gas_price_data = ntrl_gas_price_res.json()

# %%
#ntrl_gas_price_data

# %%
ntrl_gas_price_data_mapped = ntrl_gas_price_data['response']['data']

# %%
ng_df = pd.DataFrame(ntrl_gas_price_data_mapped)

# %%
ng_df
# Out:
#           period duoarea area-name product product-name process process-name  \
# 0     2023-08-18     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 1     2023-08-17     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 2     2023-08-16     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 3     2023-08-15     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 4     2023-08-14     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# ...          ...     ...       ...     ...          ...     ...          ...
# 1429  2018-01-08     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 1430  2018-01-05     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 1431  2018-01-04     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 1432  2018-01-03     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
# 1433  2018-01-02     RGC        NA    EPG0  Natural Gas     PS0   Spot Price
#
#        series                                 series-description  value  \
# 0     RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   2.44
# 1     RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   2.56
# 2     RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   2.55
# 3     RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   2.65
# 4     RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   2.74
# ...       ...                                                ...    ...
# 1429  RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   2.89
# 1430  RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...    NaN
# 1431  RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   4.65
# 1432  RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   6.24
# 1433  RNGWHHD  Henry Hub Natural Gas Spot Price (Dollars per ...   6.24
#
#         units
# 0     $/MMBTU
# 1     $/MMBTU
# 2     $/MMBTU
# 3     $/MMBTU
# 4     $/MMBTU
# ...       ...
# 1429  $/MMBTU
# 1430  $/MMBTU
# 1431  $/MMBTU
# 1432  $/MMBTU
# 1433  $/MMBTU
#
# [1434 rows x 11 columns]

# %%
ng_df.iloc[0]
# Out:
# period                                                       2023-08-18
# duoarea                                                             RGC
# area-name                                                            NA
# product                                                            EPG0
# product-name                                                Natural Gas
# process                                                             PS0
# process-name                                                 Spot Price
# series                                                          RNGWHHD
# series-description    Henry Hub Natural Gas Spot Price (Dollars per ...
# value                                                              2.44
# units                                                           $/MMBTU
# Name: 0, dtype: object

# %%
ng_df.to_csv('./data/natural_gas_prices.csv', index_label='Index')

# %% [markdown]
# ### Electricity Demand

# %%
def get_electric_demand():
    # Electric Demand
    # GET https://api.eia.gov/v2/electricity/rto/daily-region-sub-ba-data/data/

    try:
        response = requests.get(
            url="https://api.eia.gov/v2/electricity/rto/daily-region-sub-ba-data/data/",
            params={
                "frequency": "daily",
                "data[0]": "value",
                "facets[subba][]": "PGAE",
                "facets[timezone][]": "Pacific",
                "facets[parent][]": "CISO",
                "start": "2018-01-01",
                "end": "2023-08-20",
                "sort[0][column]": "period",
                "sort[0][direction]": "desc",
                "offset": "0",
                "length": "5000",
                "api_key": EIA_API_KEY,
            },
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        #print('Response HTTP Response Body: {content}'.format(
        #    content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
elec_demand_res = get_electric_demand()
# Out:
# Response HTTP Status Code: 200

# %%
elec_demand_data = elec_demand_res.json()

# %%
elec_demand_data_mapped = elec_demand_data['response']['data']

# %%
ed_df = pd.DataFrame(elec_demand_data_mapped)

# %%
ed_df.head()
# Out:
#        period subba                subba-name parent  \
# 0  2023-08-20  PGAE  Pacific Gas and Electric   CISO
# 1  2023-08-19  PGAE  Pacific Gas and Electric   CISO
# 2  2023-08-18  PGAE  Pacific Gas and Electric   CISO
# 3  2023-08-17  PGAE  Pacific Gas and Electric   CISO
# 4  2023-08-16  PGAE  Pacific Gas and Electric   CISO
#
#                               parent-name timezone   value    value-units
# 0  California Independent System Operator  Pacific  295461  megawatthours
# 1  California Independent System Operator  Pacific  302228  megawatthours
# 2  California Independent System Operator  Pacific  343391  megawatthours
# 3  California Independent System Operator  Pacific  371562  megawatthours
# 4  California Independent System Operator  Pacific  377398  megawatthours

# %%
ed_df.to_csv('./data/electricity_demand.csv', index_label='Index')

# %% [markdown]
# ## Weather / Climate (ACIS)

# %%
def get_daily_max_temp():
    # KBLU daily max temp
    # POST https://data.rcc-acis.org/StnData

    try:
        response = requests.post(
            url="https://data.rcc-acis.org/StnData",
            headers={
                "Content-Type": "application/json; charset=utf-8",
            },
            data=json.dumps({
                "sid": "KBLU 5",
                "meta": [
                    "name",
                    "state",
                    "valid_daterange",
                    "sids"
                ],
                "elems": [
                    {
                        "name": "maxt",
                        "duration": "dly",
                        "interval": "dly"
                    }
                ],
                "sDate": "2018-01-01",
                "eDate": "2023-08-20"
            })
        )
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        print('Response HTTP Response Body: {content}'.format(
            content=response.content))
        return response
    except requests.exceptions.RequestException:
        print('HTTP Request failed')

# %%
daily_max_temp_res = get_daily_max_temp()
# Out:
# Response HTTP Status Code: 200
# Response HTTP Response Body: b'{"meta":{"state": "CA", "sids": ["23225 1", "040897 2", "BLU 3", "KBLU 5", "USW00023225 6", "BLU 7", "USW00023225 32"], "name": "BLUE CANYON NYACK AP", "valid_daterange": [["1943-12-01", "2023-08-24"]]},\n"data":[["2018-01-01","58"],\n["2018-01-02","59"],\n["2018-01-03","60"],\n["2018-01-04","49"],\n["2018-01-05","46"],\n["2018-01-06","45"],\n["2018-01-07","47"],\n["2018-01-08","45"],\n["2018-01-09","45"],\n["2018-01-10","40"],\n["2018-01-11","46"],\n["2018-01-12","55"],\n["2018-01-13","64"],\n["2018-01-14","58"],\n["2018-01-15","56"],\n["2018-01-16","51"],\n["2018-01-17","56"],\n["2018-01-18","47"],\n["2018-01-19","35"],\n["2018-01-20","39"],\n["2018-01-21","37"],\n["2018-01-22","38"],\n["2018-01-23","46"],\n["2018-01-24","43"],\n["2018-01-25","31"],\n["2018-01-26","32"],\n["2018-01-27","47"],\n["2018-01-28","66"],\n["2018-01-29","62"],\n["2018-01-30","57"],\n["2018-01-31","58"],\n["2018-02-01","63"],\n["2018-02-02","65"],\n["2018-02-03","67"],\n["2018-02-04","63"],\n["2018-02-05","60"],\n["2018-02-06","59"],\n["2018-02-07","61"],\n["2018-02-08","63"],\n["2018-02-09","62"],\n["2018-02-10","51"],\n["2018-02-11","47"],\n["2018-02-12","40"],\n["2018-02-13","46"],\n["2018-02-14","42"],\n["2018-02-15","50"],\n["2018-02-16","52"],\n["2018-02-17","53"],\n["2018-02-18","39"],\n["2018-02-19","27"],\n["2018-02-20","29"],\n["2018-02-21","35"],\n["2018-02-22","26"],\n["2018-02-23","34"],\n["2018-02-24","31"],\n["2018-02-25","43"],\n["2018-02-26","29"],\n["2018-02-27","41"],\n["2018-02-28","36"],\n["2018-03-01","32"],\n["2018-03-02","26"],\n["2018-03-03","26"],\n["2018-03-04","33"],\n["2018-03-05","60"],\n["2018-03-06","M"],\n["2018-03-07","67"],\n["2018-03-08","46"],\n["2018-03-09","45"],\n["2018-03-10","44"],\n["2018-03-11","52"],\n["2018-03-12","53"],\n["2018-03-13","45"],\n["2018-03-14","31"],\n["2018-03-15","31"],\n["2018-03-16","30"],\n["2018-03-17","30"],\n["2018-03-18","39"],\n["2018-03-19","45"],\n["2018-03-20","42"],\n["2018-03-21","46"],\n["2018-03-22","42"],\n["2018-03-23","38"],\n["2018-03-24","30"],\n["2018-03-25","33"],\n["2018-03-26","45"],\n["2018-03-27","58"],\n["2018-03-28","64"],\n["2018-03-29","64"],\n["2018-03-30","63"],\n["2018-03-31","60"],\n["2018-04-01","59"],\n["2018-04-02","55"],\n["2018-04-03","57"],\n["2018-04-04","59"],\n["2018-04-05","53"],\n["2018-04-06","47"],\n["2018-04-07","48"],\n["2018-04-08","53"],\n["2018-04-09","67"],\n["2018-04-10","58"],\n["2018-04-11","48"],\n["2018-04-12","35"],\n["2018-04-13","54"],\n["2018-04-14","58"],\n["2018-04-15","50"],\n["2018-04-16","29"],\n["2018-04-17","43"],\n["2018-04-18","40"],\n["2018-04-19","48"],\n["2018-04-20","62"],\n["2018-04-21","67"],\n["2018-04-22","65"],\n["2018-04-23","67"],\n["2018-04-24","68"],\n["2018-04-25","71"],\n["2018-04-26","68"],\n["2018-04-27","50"],\n["2018-04-28","45"],\n["2018-04-29","42"],\n["2018-04-30","46"],\n["2018-05-01","56"],\n["2018-05-02","58"],\n["2018-05-03","62"],\n["2018-05-04","68"],\n["2018-05-05","67"],\n["2018-05-06","63"],\n["2018-05-07","70"],\n["2018-05-08","71"],\n["2018-05-09","63"],\n["2018-05-10","64"],\n["2018-05-11","58"],\n["2018-05-12","60"],\n["2018-05-13","60"],\n["2018-05-14","66"],\n["2018-05-15","61"],\n["2018-05-16","54"],\n["2018-05-17","54"],\n["2018-05-18","64"],\n["2018-05-19","64"],\n["2018-05-20","61"],\n["2018-05-21","62"],\n["2018-05-22","62"],\n["2018-05-23","61"],\n["2018-05-24","65"],\n["2018-05-25","49"],\n["2018-05-26","48"],\n["2018-05-27","69"],\n["2018-05-28","72"],\n["2018-05-29","74"],\n["2018-05-30","66"],\n["2018-05-31","53"],\n["2018-06-01","69"],\n["2018-06-02","76"],\n["2018-06-03","77"],\n["2018-06-04","73"],\n["2018-06-05","69"],\n["2018-06-06","67"],\n["2018-06-07","67"],\n["2018-06-08","68"],\n["2018-06-09","56"],\n["2018-06-10","62"],\n["2018-06-11","73"],\n["2018-06-12","77"],\n["2018-06-13","77"],\n["2018-06-14","75"],\n["2018-06-15","70"],\n["2018-06-16","66"],\n["2018-06-17","58"],\n["2018-06-18","67"],\n["2018-06-19","74"],\n["2018-06-20","74 ...

# %%
daily_max_temp_data = daily_max_temp_res.json()

# %%
daily_max_temp_data_mapped = daily_max_temp_data['data']

# %%
daily_max_temp_data_mapped
# Out:
# [['2018-01-01', '58'],
#  ['2018-01-02', '59'],
#  ['2018-01-03', '60'],
#  ['2018-01-04', '49'],
#  ['2018-01-05', '46'],
#  ['2018-01-06', '45'],
#  ['2018-01-07', '47'],
#  ['2018-01-08', '45'],
#  ['2018-01-09', '45'],
#  ['2018-01-10', '40'],
#  ['2018-01-11', '46'],
#  ['2018-01-12', '55'],
#  ['2018-01-13', '64'],
#  ['2018-01-14', '58'],
#  ['2018-01-15', '56'],
#  ['2018-01-16', '51'],
#  ['2018-01-17', '56'],
#  ['2018-01-18', '47'],
#  ['2018-01-19', '35'],
#  ['2018-01-20', '39'],
#  ['2018-01-21', '37'],
#  ['2018-01-22', '38'],
#  ['2018-01-23', '46'],
#  ['2018-01-24', '43'],
#  ['2018-01-25', '31'],
#  ['2018-01-26', '32'],
#  ['2018-01-27', '47'],
#  ['2018-01-28', '66'],
#  ['2018-01-29', '62'],
#  ['2018-01-30', '57'],
#  ['2018-01-31', '58'],
#  ['2018-02-01', '63'],
#  ['2018-02-02', '65'],
#  ['2018-02-03', '67'],
#  ['2018-02-04', '63'],
#  ['2018-02-05', '60'],
#  ['2018-02-06', '59'],
#  ['2018-02-07', '61'],
#  ['2018-02-08', '63'],
#  ['2018-02-09', '62'],
#  ['2018-02-10', '51'],
#  ['2018-02-11', '47'],
#  ['2018-02-12', '40'],
#  ['2018-02-13', '46'],
#  ['2018-02-14', '42'],
#  ['2018-02-15', '50'],
#  ['2018-02-16', '52'],
#  ['2018-02-17', '53'],
#  ['2018-02-18', '39'],
#  ['2018-02-19', '27'],
#  ['2018-02-20', '29'],
#  ['2018-02-21', '35'],
#  ['2018-02-22', '26'],
#  ['2018-02-23', '34'],
#  ['2018-02-24', '31'],
#  ['2018-02-25', '43'],
#  ['2018-02-26', '29'],
#  ['2018-02-27', '41'],
#  ['2018-02-28', '36'],
#  ['2018-03-01', '32'],
#  ['2018-03-02', '26'],
#  ['2018-03-03', '26'],
#  ['2018-03-04', '33'],
#  ['2018-03-05', '60'],
#  ['2018-03-06', 'M'],
#  ['2018-03-07', '67'],
#  ['2018-03-08', '46'],
#  ['2018-03-09', '45'],
#  ['2018-03-10', '44'],
#  ['2018-03-11', '52'],
#  ['2018-03-12', '53'],
#  ['2018-03-13', '45'],
#  ['2018-03-14', '31'],
#  ['2018-03-15', '31'],
#  ['2018-03-16', '30'],
#  ['2018-03-17', '30'],
#  ['2018-03-18', '39'],
#  ['2018-03-19', '45'],
#  ['2018-03-20', '42'],
#  ['2018-03-21', '46'],
#  ['2018-03-22', '42'],
#  ['2018-03-23', '38'],
#  ['2018-03-24', '30'],
#  ['2018-03-25', '33'],
#  ['2018-03-26', '45'],
#  ['2018-03-27', '58'],
#  ['2018-03-28', '64'],
#  ['2018-03-29', '64'],
#  ['2018-03-30', '63'],
#  ['2018-03-31', '60'],
#  ['2018-04-01', '59'],
#  ['2018-04-02', '55'],
#  ['2018-04-03', '57'],
#  ['2018-04-04', '59'],
#  ['2018-04-05', '53'],
#  ['2018-04-06', '47'],
#  ['2018-04-07', '48'],
#  ['2018-04-08', '53'],
#  ['2018-04-09', '67'],
#  ['2018-04-10', '58'],
#  ['2018-04-11', '48'],
#  ['2018-04-12', '35'],
#  ['2018-04-13', '54'],
#  ['2018-04-14', '58'],
#  ['2018-04-15', '50'],
#  ['2018-04-16', '29'],
#  ['2018-04-17', '43'],
#  ['2018-04-18', '40'],
#  ['2018-04-19', '48'],
#  ['2018-04-20', '62'],
#  ['2018-04-21', '67'],
#  ['2018-04-22', '65'],
#  ['2018-04-23', '67'],
#  ['2018-04-24', '68'],
#  ['2018-04-25', '71'],
#  ['2018-04-26', '68'],
#  ['2018-04-27', '50'],
#  ['2018-04-28', '45'],
#  ['2018-04-29', '42'],
#  ['2018-04-30', '46'],
#  ['2018-05-01', '56'],
#  ['2018-05-02', '58'],
#  ['2018-05-03', '62'],
#  ['2018-05-04', '68'],
#  ['2018-05-05', '67'],
#  ['2018-05-06', '63'],
#  ['2018-05-07', '70'],
#  ['2018-05-08', '71'],
#  ['2018-05-09', '63'],
#  ['2018-05-10', '64'],
#  ['2018-05-11', '58'],
#  ['2018-05-12', '60'],
#  ['2018-05-13', '60'],
#  ['2018-05-14', '66'],
#  ['2018-05-15', '61'],
#  ['2018-05-16', '54'],
#  ['2018-05-17', '54'],
#  ['2018-05-18', '64'],
#  ['2018-05-19', '64'],
#  ['2018-05-20', '61'],
#  ['2018-05-21', '62'],
#  ['2018-05-22', '62'],
#  ['2018-05-23', '61'],
#  ['2018-05-24', '65'],
#  ['2018-05-25', '49'],
#  ['2018-05-26', '48'],
#  ['2018-05-27', '69'],
#  ['2018-05-28', '72'],
#  ['2018-05-29', '74'],
#  ['2018-05-30', '66'],
#  ['2018-05-31', '53'],
#  ['2018-06-01', '69'],
#  ['2018-06-02', '76'],
#  ['2018-06-03', '77'],
#  ['2018-06-04', '73'],
#  ['2018-06-05', '69'],
#  ['2018-06-06', '67'],
#  ['2018-06-07', '67'],
#  ['2018-06-08', '68'],
#  ['2018-06-09', '56'],
#  ['2018-06-10', '62'],
#  ['2018-06-11', '73'],
#  ['2018-06-12', '77'],
#  ['2018-06-13', '77'],
#  ['2018-06-14', '75'],
#  ['2018-06-15', '70'],
#  ['2018-06-16', '66'],
#  ['2018-06-17', '58'],
#  ['2018-06-18', '67'],
#  ['2018-06-19', '74'],
#  ['2018-06-20', '74'],
#  ['2018-06-21', '77'],
#  ['2018-06-22', '81'],
#  ['2018-06-23', '82'],
#  ['2018-06-24', '82'],
#  ['2018-06-25', '77'],
#  ['2018-06-26', '77'],
#  ['2018-06-27', '75'],
#  ['2018-06-28', '69'],
#  ['2018-06-29', '74'],
#  ['2018-06-30', '84'],
#  ['2018-07-01', '83'],
#  ['2018-07-02', '82'],
#  ['2018-07-03', '74'],
#  ['2018-07-04', '69'],
#  ['2018-07-05', '71'],
#  ['2018-07-06', '77'],
#  ['2018-07-07', '79'],
#  ['2018-07-08', '79'],
#  ['2018-07-09', '79'],
#  ['2018-07-10', '79'],
#  ['2018-07-11', '81'],
#  ['2018-07-12', '82'],
#  ['2018-07-13', '79'],
#  ['2018-07-14', '82'],
#  ['2018-07-15', '83'],
#  ['2018-07-16', '84'],
#  ['2018-07-17', '84'],
#  ['2018-07-18', '86'],
#  ['2018-07-19', '86'],
#  ['2018-07-20', '81'],
#  ['2018-07-21', '80'],
#  ['2018-07-22', '80'],
#  ['2018-07-23', '83'],
#  ['2018-07-24', '84'],
#  ['2018-07-25', '88'],
#  ['2018-07-26', '89'],
#  ['2018-07-27', '86'],
#  ['2018-07-28', '85'],
#  ['2018-07-29', '83'],
#  ['2018-07-30', '84'],
#  ['2018-07-31', '86'],
#  ['2018-08-01', '84'],
#  ['2018-08-02', '82'],
#  ['2018-08-03', '80'],
#  ['2018-08-04', '76'],
#  ['2018-08-05', '76'],
#  ['2018-08-06', '79'],
#  ['2018-08-07', '81'],
#  ['2018-08-08', '83'],
#  ['2018-08-09', '85'],
#  ['2018-08-10', '87'],
#  ['2018-08-11', '84'],
#  ['2018-08-12', '82'],
#  ['2018-08-13', '81'],
#  ['2018-08-14', '80'],
#  ['2018-08-15', '80'],
#  ['2018-08-16', '80'],
#  ['2018-08-17', '81'],
#  ['2018-08-18', '83'],
#  ['2018-08-19', '83'],
#  ['2018-08-20', '80'],
#  ['2018-08-21', '76'],
#  ['2018-08-22', '75'],
#  ['2018-08-23', '74'],
#  ['2018-08-24', '71'],
#  ['2018-08-25', '73'],
#  ['2018-08-26', '72'],
#  ['2018-08-27', '71'],
#  ['2018-08-28', '71'],
#  ['2018-08-29', '72'],
#  ['2018-08-30', '68'],
#  ['2018-08-31', '70'],
#  ['2018-09-01', '78'],
#  ['2018-09-02', '84'],
#  ['2018-09-03', '83'],
#  ['2018-09-04', '82'],
#  ['2018-09-05', '79'],
#  ['2018-09-06', '79'],
#  ['2018-09-07', '81'],
#  ['2018-09-08', '78'],
#  ['2018-09-09', '78'],
#  ['2018-09-10', '76'],
#  ['2018-09-11', '73'],
#  ['2018-09-12', '61'],
#  ['2018-09-13', '60'],
#  ['2018-09-14', '65'],
#  ['2018-09-15', '61'],
#  ['2018-09-16', '66'],
#  ['2018-09-17', '67'],
#  ['2018-09-18', '68'],
#  ['2018-09-19', '68'],
#  ['2018-09-20', '75'],
#  ['2018-09-21', '75'],
#  ['2018-09-22', '73'],
#  ['2018-09-23', '71'],
#  ['2018-09-24', '75'],
#  ['2018-09-25', '80'],
#  ['2018-09-26', '82'],
#  ['2018-09-27', '81'],
#  ['2018-09-28', '77'],
#  ['2018-09-29', '60'],
#  ['2018-09-30', '63'],
#  ['2018-10-01', '64'],
#  ['2018-10-02', '67'],
#  ['2018-10-03', '59'],
#  ['2018-10-04', '48'],
#  ['2018-10-05', '58'],
#  ['2018-10-06', '58'],
#  ['2018-10-07', '61'],
#  ['2018-10-08', '65'],
#  ['2018-10-09', '60'],
#  ['2018-10-10', '56'],
#  ['2018-10-11', '61'],
#  ['2018-10-12', '69'],
#  ['2018-10-13', '70'],
#  ['2018-10-14', '60'],
#  ['2018-10-15', '67'],
#  ['2018-10-16', '68'],
#  ['2018-10-17', '65'],
#  ['2018-10-18', '65'],
#  ['2018-10-19', '73'],
#  ['2018-10-20', '68'],
#  ['2018-10-21', '66'],
#  ['2018-10-22', '64'],
#  ['2018-10-23', '60'],
#  ['2018-10-24', '63'],
#  ['2018-10-25', '68'],
#  ['2018-10-26', '69'],
#  ['2018-10-27', '67'],
#  ['2018-10-28', '62'],
#  ['2018-10-29', '54'],
#  ['2018-10-30', '62'],
#  ['2018-10-31', '66'],
#  ['2018-11-01', '68'],
#  ['2018-11-02', '67'],
#  ['2018-11-03', '71'],
#  ['2018-11-04', '65'],
#  ['2018-11-05', '63'],
#  ['2018-11-06', '65'],
#  ['2018-11-07', '58'],
#  ['2018-11-08', '54'],
#  ['2018-11-09', '60'],
#  ['2018-11-10', '57'],
#  ['2018-11-11', '60'],
#  ['2018-11-12', '61'],
#  ['2018-11-13', '56'],
#  ['2018-11-14', '61'],
#  ['2018-11-15', '60'],
#  ['2018-11-16', '61'],
#  ['2018-11-17', '59'],
#  ['2018-11-18', '60'],
#  ['2018-11-19', '58'],
#  ['2018-11-20', '57'],
#  ['2018-11-21', '46'],
#  ['2018-11-22', '37'],
#  ['2018-11-23', '44'],
#  ['2018-11-24', '48'],
#  ['2018-11-25', '51'],
#  ['2018-11-26', '52'],
#  ['2018-11-27', '47'],
#  ['2018-11-28', '41'],
#  ['2018-11-29', '39'],
#  ['2018-11-30', '36'],
#  ['2018-12-01', '31'],
#  ['2018-12-02', '33'],
#  ['2018-12-03', '38'],
#  ['2018-12-04', '42'],
#  ['2018-12-05', '39'],
#  ['2018-12-06', '46'],
#  ['2018-12-07', '44'],
#  ['2018-12-08', 'M'],
#  ['2018-12-09', '46'],
#  ['2018-12-10', '47'],
#  ['2018-12-11', '54'],
#  ['2018-12-12', '53'],
#  ['2018-12-13', '56'],
#  ['2018-12-14', '49'],
#  ['2018-12-15', '48'],
#  ['2018-12-16', '45'],
#  ['2018-12-17', '40'],
#  ['2018-12-18', '42'],
#  ['2018-12-19', '58'],
#  ['2018-12-20', '50'],
#  ['2018-12-21', '41'],
#  ['2018-12-22', '53'],
#  ['2018-12-23', '45'],
#  ['2018-12-24', '40'],
#  ['2018-12-25', '40'],
#  ['2018-12-26', '49'],
#  ['2018-12-27', '35'],
#  ['2018-12-28', '40'],
#  ['2018-12-29', '57'],
#  ['2018-12-30', '48'],
#  ['2018-12-31', '33'],
#  ['2019-01-01', '40'],
#  ['2019-01-02', '52'],
#  ['2019-01-03', '49'],
#  ['2019-01-04', '46'],
#  ['2019-01-05', '41'],
#  ['2019-01-06', '35'],
#  ['2019-01-07', '43'],
#  ['2019-01-08', '46'],
#  ['2019-01-09', '39'],
#  ['2019-01-10', '46'],
#  ['2019-01-11', '50'],
#  ['2019-01-12', '49'],
#  ['2019-01-13', '48'],
#  ['2019-01-14', '42'],
#  ['2019-01-15', '36'],
#  ['2019-01-16', '41'],
#  ['2019-01-17', '39'],
#  ['2019-01-18', '40'],
#  ['2019-01-19', '46'],
#  ['2019-01-20', '43'],
#  ['2019-01-21', '34'],
#  ['2019-01-22', '46'],
#  ['2019-01-23', '52'],
#  ['2019-01-24', '58'],
#  ['2019-01-25', '60'],
#  ['2019-01-26', '61'],
#  ['2019-01-27', '62'],
#  ['2019-01-28', '60'],
#  ['2019-01-29', '55'],
#  ['2019-01-30', '51'],
#  ['2019-01-31', '53'],
#  ['2019-02-01', '44'],
#  ['2019-02-02', '41'],
#  ['2019-02-03', '35'],
#  ['2019-02-04', '30'],
#  ['2019-02-05', '24'],
#  ['2019-02-06', '25'],
#  ['2019-02-07', '28'],
#  ['2019-02-08', '30'],
#  ['2019-02-09', '29'],
#  ['2019-02-10', '24'],
#  ['2019-02-11', '29'],
#  ['2019-02-12', '40'],
#  ['2019-02-13', '43'],
#  ['2019-02-14', '44'],
#  ['2019-02-15', '28'],
#  ['2019-02-16', '27'],
#  ['2019-02-17', '26'],
#  ['2019-02-18', '31'],
#  ['2019-02-19', '36'],
#  ['2019-02-20', '29'],
#  ['2019-02-21', '29'],
#  ['2019-02-22', '37'],
#  ['2019-02-23', '35'],
#  ['2019-02-24', '35'],
#  ['2019-02-25', '36'],
#  ['2019-02-26', '33'],
#  ['2019-02-27', '38'],
#  ['2019-02-28', '35'],
#  ['2019-03-01', '38'],
#  ['2019-03-02', '41'],
#  ['2019-03-03', '39'],
#  ['2019-03-04', '38'],
#  ['2019-03-05', '39'],
#  ['2019-03-06', '39'],
#  ['2019-03-07', '34'],
#  ['2019-03-08', '30'],
#  ['2019-03-09', '28'],
#  ['2019-03-10', '39'],
#  ['2019-03-11', '46'],
#  ['2019-03-12', '42'],
#  ['2019-03-13', '40'],
#  ['2019-03-14', '51'],
#  ['2019-03-15', '52'],
#  ['2019-03-16', '55'],
#  ['2019-03-17', '56'],
#  ['2019-03-18', '57'],
#  ['2019-03-19', '56'],
#  ['2019-03-20', '41'],
#  ['2019-03-21', '41'],
#  ['2019-03-22', '37'],
#  ['2019-03-23', '36'],
#  ['2019-03-24', '46'],
#  ['2019-03-25', '45'],
#  ['2019-03-26', '41'],
#  ['2019-03-27', '42'],
#  ['2019-03-28', '37'],
#  ['2019-03-29', '44'],
#  ['2019-03-30', '52'],
#  ['2019-03-31', '57'],
#  ['2019-04-01', '52'],
#  ['2019-04-02', '41'],
#  ['2019-04-03', '45'],
#  ['2019-04-04', '43'],
#  ['2019-04-05', '37'],
#  ['2019-04-06', '45'],
#  ['2019-04-07', '51'],
#  ['2019-04-08', '50'],
#  ['2019-04-09', '45'],
#  ['2019-04-10', '54'],
#  ['2019-04-11', '45'],
#  ['2019-04-12', '53'],
#  ['2019-04-13', '55'],
#  ['2019-04-14', '50'],
#  ['2019-04-15', '44'],
#  ['2019-04-16', '49'],
#  ['2019-04-17', '62'],
#  ['2019-04-18', '69'],
#  ['2019-04-19', '67'],
#  ['2019-04-20', '53'],
#  ['2019-04-21', '57'],
#  ['2019-04-22', '65'],
#  ['2019-04-23', '73'],
#  ['2019-04-24', '72'],
#  ['2019-04-25', '72'],
#  ['2019-04-26', '70'],
#  ['2019-04-27', '68'],
#  ['2019-04-28', '65'],
#  ['2019-04-29', '61'],
#  ['2019-04-30', '46'],
#  ['2019-05-01', '56'],
#  ['2019-05-02', '61'],
#  ['2019-05-03', '62'],
#  ['2019-05-04', '64'],
#  ['2019-05-05', '64'],
#  ['2019-05-06', '59'],
#  ['2019-05-07', '61'],
#  ['2019-05-08', '68'],
#  ['2019-05-09', '67'],
#  ['2019-05-10', '66'],
#  ['2019-05-11', '70'],
#  ['2019-05-12', '69'],
#  ['2019-05-13', '65'],
#  ['2019-05-14', '62'],
#  ['2019-05-15', '52'],
#  ['2019-05-16', '41'],
#  ['2019-05-17', '43'],
#  ['2019-05-18', '44'],
#  ['2019-05-19', '36'],
#  ['2019-05-20', '45'],
#  ['2019-05-21', '36'],
#  ['2019-05-22', '52'],
#  ['2019-05-23', '55'],
#  ['2019-05-24', '56'],
#  ['2019-05-25', '54'],
#  ['2019-05-26', '42'],
#  ['2019-05-27', '44'],
#  ['2019-05-28', '64'],
#  ['2019-05-29', '64'],
#  ['2019-05-30', '61'],
#  ['2019-05-31', '67'],
#  ['2019-06-01', '69'],
#  ['2019-06-02', '68'],
#  ['2019-06-03', '72'],
#  ['2019-06-04', '77'],
#  ['2019-06-05', '75'],
#  ['2019-06-06', '65'],
#  ['2019-06-07', '57'],
#  ['2019-06-08', '68'],
#  ['2019-06-09', '75'],
#  ['2019-06-10', '79'],
#  ['2019-06-11', '82'],
#  ['2019-06-12', '80'],
#  ['2019-06-13', '76'],
#  ['2019-06-14', '76'],
#  ['2019-06-15', '74'],
#  ['2019-06-16', '75'],
#  ['2019-06-17', '79'],
#  ['2019-06-18', '81'],
#  ['2019-06-19', '79'],
#  ['2019-06-20', '69'],
#  ['2019-06-21', '67'],
#  ['2019-06-22', '75'],
#  ['2019-06-23', '73'],
#  ['2019-06-24', '72'],
#  ['2019-06-25', '69'],
#  ['2019-06-26', '62'],
#  ['2019-06-27', '60'],
#  ['2019-06-28', '62'],
#  ['2019-06-29', '66'],
#  ['2019-06-30', '69'],
#  ['2019-07-01', '69'],
#  ['2019-07-02', '69'],
#  ['2019-07-03', '69'],
#  ['2019-07-04', '71'],
#  ['2019-07-05', '75'],
#  ['2019-07-06', '74'],
#  ['2019-07-07', '71'],
#  ['2019-07-08', '67'],
#  ['2019-07-09', '70'],
#  ['2019-07-10', '73'],
#  ['2019-07-11', '77'],
#  ['2019-07-12', '79'],
#  ['2019-07-13', '79'],
#  ['2019-07-14', '76'],
#  ['2019-07-15', '76'],
#  ['2019-07-16', '73'],
#  ['2019-07-17', '75'],
#  ['2019-07-18', '75'],
#  ['2019-07-19', '74'],
#  ['2019-07-20', '74'],
#  ['2019-07-21', '75'],
#  ['2019-07-22', '79'],
#  ['2019-07-23', '79'],
#  ['2019-07-24', '81'],
#  ['2019-07-25', '81'],
#  ['2019-07-26', '79'],
#  ['2019-07-27', '84'],
#  ['2019-07-28', '83'],
#  ['2019-07-29', '79'],
#  ['2019-07-30', '76'],
#  ['2019-07-31', '78'],
#  ['2019-08-01', '76'],
#  ['2019-08-02', '78'],
#  ['2019-08-03', '79'],
#  ['2019-08-04', '78'],
#  ['2019-08-05', '79'],
#  ['2019-08-06', '80'],
#  ['2019-08-07', '79'],
#  ['2019-08-08', '74'],
#  ['2019-08-09', '68'],
#  ['2019-08-10', '63'],
#  ['2019-08-11', '70'],
#  ['2019-08-12', '75'],
#  ['2019-08-13', '79'],
#  ['2019-08-14', '84'],
#  ['2019-08-15', '85'],
#  ['2019-08-16', '83'],
#  ['2019-08-17', '79'],
#  ['2019-08-18', '74'],
#  ['2019-08-19', '74'],
#  ['2019-08-20', '76'],
#  ['2019-08-21', '77'],
#  ['2019-08-22', '77'],
#  ['2019-08-23', '80'],
#  ['2019-08-24', '80'],
#  ['2019-08-25', '80'],
#  ['2019-08-26', '85'],
#  ['2019-08-27', '84'],
#  ['2019-08-28', '82'],
#  ['2019-08-29', '77'],
#  ['2019-08-30', '77'],
#  ['2019-08-31', '78'],
#  ['2019-09-01', '79'],
#  ['2019-09-02', '79'],
#  ['2019-09-03', '80'],
#  ['2019-09-04', '82'],
#  ['2019-09-05', '79'],
#  ['2019-09-06', '76'],
#  ['2019-09-07', '72'],
#  ['2019-09-08', '63'],
#  ['2019-09-09', '63'],
#  ['2019-09-10', '61'],
#  ['2019-09-11', '69'],
#  ['2019-09-12', '74'],
#  ['2019-09-13', '78'],
#  ['2019-09-14', '79'],
#  ['2019-09-15', '73'],
#  ['2019-09-16', '54'],
#  ['2019-09-17', '60'],
#  ['2019-09-18', '51'],
#  ['2019-09-19', '55'],
#  ['2019-09-20', '62'],
#  ['2019-09-21', '67'],
#  ['2019-09-22', '66'],
#  ['2019-09-23', '71'],
#  ['2019-09-24', '83'],
#  ['2019-09-25', '83'],
#  ['2019-09-26', '76'],
#  ['2019-09-27', '65'],
#  ['2019-09-28', '50'],
#  ['2019-09-29', '42'],
#  ['2019-09-30', '42'],
#  ['2019-10-01', '52'],
#  ['2019-10-02', '58'],
#  ['2019-10-03', '56'],
#  ['2019-10-04', '57'],
#  ['2019-10-05', '64'],
#  ['2019-10-06', '70'],
#  ['2019-10-07', '70'],
#  ['2019-10-08', '68'],
#  ['2019-10-09', '60'],
#  ['2019-10-10', '62'],
#  ['2019-10-11', '62'],
#  ['2019-10-12', '62'],
#  ['2019-10-13', '60'],
#  ['2019-10-14', '64'],
#  ['2019-10-15', '65'],
#  ['2019-10-16', '64'],
#  ['2019-10-17', '49'],
#  ['2019-10-18', '53'],
#  ['2019-10-19', '47'],
#  ['2019-10-20', '61'],
#  ['2019-10-21', '70'],
#  ['2019-10-22', '72'],
#  ['2019-10-23', '66'],
#  ['2019-10-24', '71'],
#  ['2019-10-25', '71'],
#  ['2019-10-26', '67'],
#  ['2019-10-27', '44'],
#  ['2019-10-28', '53'],
#  ['2019-10-29', '52'],
#  ['2019-10-30', 'M'],
#  ['2019-10-31', 'M'],
#  ['2019-11-01', '67'],
#  ['2019-11-02', '66'],
#  ['2019-11-03', '67'],
#  ['2019-11-04', '70'],
#  ['2019-11-05', '68'],
#  ['2019-11-06', '65'],
#  ['2019-11-07', '66'],
#  ['2019-11-08', '68'],
#  ['2019-11-09', '67'],
#  ['2019-11-10', '68'],
#  ['2019-11-11', '70'],
#  ['2019-11-12', '65'],
#  ['2019-11-13', '64'],
#  ['2019-11-14', '61'],
#  ['2019-11-15', '57'],
#  ['2019-11-16', '69'],
#  ['2019-11-17', '70'],
#  ['2019-11-18', '67'],
#  ['2019-11-19', '54'],
#  ['2019-11-20', '42'],
#  ['2019-11-21', '46'],
#  ['2019-11-22', '48'],
#  ['2019-11-23', '55'],
#  ['2019-11-24', '56'],
#  ['2019-11-25', '44'],
#  ['2019-11-26', '33'],
#  ['2019-11-27', '26'],
#  ['2019-11-28', '32'],
#  ['2019-11-29', '26'],
#  ['2019-11-30', '36'],
#  ['2019-12-01', '39'],
#  ['2019-12-02', '43'],
#  ['2019-12-03', '54'],
#  ['2019-12-04', '48'],
#  ['2019-12-05', '45'],
#  ['2019-12-06', '47'],
#  ['2019-12-07', '42'],
#  ['2019-12-08', '42'],
#  ['2019-12-09', '47'],
#  ['2019-12-10', '49'],
#  ['2019-12-11', '42'],
#  ['2019-12-12', '44'],
#  ['2019-12-13', '43'],
#  ['2019-12-14', '37'],
#  ['2019-12-15', '33'],
#  ['2019-12-16', '46'],
#  ['2019-12-17', '44'],
#  ['2019-12-18', '36'],
#  ['2019-12-19', '45'],
#  ['2019-12-20', '48'],
#  ['2019-12-21', '48'],
#  ['2019-12-22', '47'],
#  ['2019-12-23', '38'],
#  ['2019-12-24', '31'],
#  ['2019-12-25', '32'],
#  ['2019-12-26', '39'],
#  ['2019-12-27', '45'],
#  ['2019-12-28', '50'],
#  ['2019-12-29', '45'],
#  ['2019-12-30', '48'],
#  ['2019-12-31', '55'],
#  ['2020-01-01', '49'],
#  ['2020-01-02', '53'],
#  ['2020-01-03', '56'],
#  ['2020-01-04', '46'],
#  ['2020-01-05', '40'],
#  ['2020-01-06', '52'],
#  ['2020-01-07', '48'],
#  ['2020-01-08', '33'],
#  ['2020-01-09', '36'],
#  ['2020-01-10', '44'],
#  ['2020-01-11', '32'],
#  ['2020-01-12', '32'],
#  ['2020-01-13', '31'],
#  ['2020-01-14', '32'],
#  ['2020-01-15', '34'],
#  ['2020-01-16', '34'],
#  ['2020-01-17', '34'],
#  ['2020-01-18', '49'],
#  ['2020-01-19', '56'],
#  ['2020-01-20', '48'],
#  ['2020-01-21', '38'],
#  ['2020-01-22', '47'],
#  ['2020-01-23', '52'],
#  ['2020-01-24', '44'],
#  ['2020-01-25', '52'],
#  ['2020-01-26', '41'],
#  ['2020-01-27', '43'],
#  ['2020-01-28', '38'],
#  ['2020-01-29', '53'],
#  ['2020-01-30', '55'],
#  ['2020-01-31', '63'],
#  ['2020-02-01', '63'],
#  ['2020-02-02', '48'],
#  ['2020-02-03', '32'],
#  ['2020-02-04', '41'],
#  ['2020-02-05', '54'],
#  ['2020-02-06', '60'],
#  ['2020-02-07', '59'],
#  ['2020-02-08', '49'],
#  ['2020-02-09', '40'],
#  ['2020-02-10', '55'],
#  ['2020-02-11', '59'],
#  ['2020-02-12', '57'],
#  ['2020-02-13', '51'],
#  ['2020-02-14', '52'],
#  ['2020-02-15', '51'],
#  ['2020-02-16', '50'],
#  ['2020-02-17', '55'],
#  ['2020-02-18', '50'],
#  ['2020-02-19', '50'],
#  ['2020-02-20', '52'],
#  ['2020-02-21', '55'],
#  ['2020-02-22', '55'],
#  ['2020-02-23', '50'],
#  ['2020-02-24', '57'],
#  ['2020-02-25', '62'],
#  ['2020-02-26', '59'],
#  ['2020-02-27', '63'],
#  ['2020-02-28', '57'],
#  ['2020-02-29', '51'],
#  ['2020-03-01', '35'],
#  ['2020-03-02', '48'],
#  ['2020-03-03', '65'],
#  ['2020-03-04', '62'],
#  ['2020-03-05', '59'],
#  ['2020-03-06', '57'],
#  ['2020-03-07', '40'],
#  ['2020-03-08', '35'],
#  ['2020-03-09', '45'],
#  ['2020-03-10', '58'],
#  ['2020-03-11', '51'],
#  ['2020-03-12', '62'],
#  ['2020-03-13', '51'],
#  ['2020-03-14', '34'],
#  ['2020-03-15', 'M'],
#  ['2020-03-16', 'M'],
#  ['2020-03-17', 'M'],
#  ['2020-03-18', 'M'],
#  ['2020-03-19', '37'],
#  ['2020-03-20', '44'],
#  ['2020-03-21', '47'],
#  ['2020-03-22', '47'],
#  ['2020-03-23', '41'],
#  ['2020-03-24', '32'],
#  ['2020-03-25', '30'],
#  ['2020-03-26', '36'],
#  ['2020-03-27', '38'],
#  ['2020-03-28', '36'],
#  ['2020-03-29', '37'],
#  ['2020-03-30', '40'],
#  ['2020-03-31', '45'],
#  ['2020-04-01', '41'],
#  ['2020-04-02', '46'],
#  ['2020-04-03', '46'],
#  ['2020-04-04', '38'],
#  ['2020-04-05', '33'],
#  ['2020-04-06', '39'],
#  ['2020-04-07', '46'],
#  ['2020-04-08', '59'],
#  ['2020-04-09', '40'],
#  ['2020-04-10', '53'],
#  ['2020-04-11', '55'],
#  ['2020-04-12', '53'],
#  ['2020-04-13', '54'],
#  ['2020-04-14', '58'],
#  ['2020-04-15', '58'],
#  ['2020-04-16', '60'],
#  ['2020-04-17', '55'],
#  ['2020-04-18', '51'],
#  ['2020-04-19', '50'],
#  ['2020-04-20', '48'],
#  ['2020-04-21', '59'],
#  ['2020-04-22', '61'],
#  ['2020-04-23', '63'],
#  ['2020-04-24', '69'],
#  ['2020-04-25', '66'],
#  ['2020-04-26', '66'],
#  ['2020-04-27', '66'],
#  ['2020-04-28', '74'],
#  ['2020-04-29', '68'],
#  ['2020-04-30', '59'],
#  ['2020-05-01', '62'],
#  ['2020-05-02', '57'],
#  ['2020-05-03', '57'],
#  ['2020-05-04', '63'],
#  ['2020-05-05', '64'],
#  ['2020-05-06', '68'],
#  ['2020-05-07', '75'],
#  ['2020-05-08', '76'],
#  ['2020-05-09', '74'],
#  ['2020-05-10', '69'],
#  ['2020-05-11', '57'],
#  ['2020-05-12', '42'],
#  ['2020-05-13', '46'],
#  ['2020-05-14', '44'],
#  ['2020-05-15', '58'],
#  ['2020-05-16', '62'],
#  ['2020-05-17', '47'],
#  ['2020-05-18', '40'],
#  ['2020-05-19', '42'],
#  ['2020-05-20', '52'],
#  ['2020-05-21', '59'],
#  ['2020-05-22', '55'],
#  ['2020-05-23', '64'],
#  ['2020-05-24', '70'],
#  ['2020-05-25', '75'],
#  ['2020-05-26', '78'],
#  ['2020-05-27', '79'],
#  ['2020-05-28', '83'],
#  ['2020-05-29', '80'],
#  ['2020-05-30', '56'],
#  ['2020-05-31', '60'],
#  ['2020-06-01', '64'],
#  ['2020-06-02', '76'],
#  ['2020-06-03', '78'],
#  ['2020-06-04', '79'],
#  ['2020-06-05', '72'],
#  ['2020-06-06', '53'],
#  ['2020-06-07', '48'],
#  ['2020-06-08', '61'],
#  ['2020-06-09', '69'],
#  ['2020-06-10', '74'],
#  ['2020-06-11', '74'],
#  ['2020-06-12', '61'],
#  ['2020-06-13', '52'],
#  ['2020-06-14', '64'],
#  ['2020-06-15', '62'],
#  ['2020-06-16', '59'],
#  ['2020-06-17', '71'],
#  ['2020-06-18', '74'],
#  ['2020-06-19', '76'],
#  ['2020-06-20', '76'],
#  ['2020-06-21', '77'],
#  ['2020-06-22', '81'],
#  ['2020-06-23', '82'],
#  ['2020-06-24', '81'],
#  ['2020-06-25', '82'],
#  ['2020-06-26', '88'],
#  ['2020-06-27', '81'],
#  ['2020-06-28', '64'],
#  ['2020-06-29', '67'],
#  ['2020-06-30', '68'],
#  ['2020-07-01', '72'],
#  ['2020-07-02', '72'],
#  ['2020-07-03', '71'],
#  ['2020-07-04', '74'],
#  ['2020-07-05', '76'],
#  ['2020-07-06', '75'],
#  ['2020-07-07', '72'],
#  ['2020-07-08', '75'],
#  ['2020-07-09', '76'],
#  ['2020-07-10', '82'],
#  ['2020-07-11', '82'],
#  ['2020-07-12', '82'],
#  ['2020-07-13', '80'],
#  ['2020-07-14', '79'],
#  ['2020-07-15', '82'],
#  ['2020-07-16', '80'],
#  ['2020-07-17', '80'],
#  ['2020-07-18', '81'],
#  ['2020-07-19', '83'],
#  ['2020-07-20', '80'],
#  ['2020-07-21', '81'],
#  ['2020-07-22', '76'],
#  ['2020-07-23', '76'],
#  ['2020-07-24', '77'],
#  ['2020-07-25', '79'],
#  ['2020-07-26', '81'],
#  ['2020-07-27', '81'],
#  ['2020-07-28', '82'],
#  ['2020-07-29', '81'],
#  ['2020-07-30', '81'],
#  ['2020-07-31', '81'],
#  ['2020-08-01', '82'],
#  ['2020-08-02', '80'],
#  ['2020-08-03', '80'],
#  ['2020-08-04', '78'],
#  ['2020-08-05', '74'],
#  ['2020-08-06', '72'],
#  ['2020-08-07', '74'],
#  ['2020-08-08', '79'],
#  ['2020-08-09', '82'],
#  ['2020-08-10', '83'],
#  ['2020-08-11', '79'],
#  ['2020-08-12', '78'],
#  ['2020-08-13', '82'],
#  ['2020-08-14', '87'],
#  ['2020-08-15', '89'],
#  ['2020-08-16', '86'],
#  ['2020-08-17', '90'],
#  ['2020-08-18', '87'],
#  ['2020-08-19', '81'],
#  ['2020-08-20', '82'],
#  ['2020-08-21', '78'],
#  ['2020-08-22', '82'],
#  ['2020-08-23', '83'],
#  ['2020-08-24', '79'],
#  ['2020-08-25', '78'],
#  ['2020-08-26', '78'],
#  ['2020-08-27', '78'],
#  ['2020-08-28', '81'],
#  ['2020-08-29', '80'],
#  ['2020-08-30', '81'],
#  ['2020-08-31', '79'],
#  ['2020-09-01', '85'],
#  ['2020-09-02', '82'],
#  ['2020-09-03', '84'],
#  ['2020-09-04', '87'],
#  ['2020-09-05', '93'],
#  ['2020-09-06', '90'],
#  ['2020-09-07', '89'],
#  ['2020-09-08', '77'],
#  ['2020-09-09', '78'],
#  ['2020-09-10', '71'],
#  ['2020-09-11', '76'],
#  ['2020-09-12', '80'],
#  ['2020-09-13', '80'],
#  ['2020-09-14', '78'],
#  ['2020-09-15', '78'],
#  ['2020-09-16', '76'],
#  ['2020-09-17', '74'],
#  ['2020-09-18', '64'],
#  ['2020-09-19', '70'],
#  ['2020-09-20', '75'],
#  ['2020-09-21', '73'],
#  ['2020-09-22', '71'],
#  ['2020-09-23', '74'],
#  ['2020-09-24', '71'],
#  ['2020-09-25', '72'],
#  ['2020-09-26', '72'],
#  ...]

# %%
max_temp_df = pd.DataFrame(daily_max_temp_data_mapped)

# %%
max_temp_df.head(3)
# Out:
#             0   1
# 0  2018-01-01  58
# 1  2018-01-02  59
# 2  2018-01-03  60

# %%
max_temp_df.columns = ['Date', 'MaxTemp']

# %%
# note that the MaxTemp column is a string object, not an integer cause there are some missing values that have a value of "M"
max_temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2058 entries, 0 to 2057
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2058 non-null   object
#  1   MaxTemp  2058 non-null   object
# dtypes: object(2)
# memory usage: 32.3+ KB

# %%
max_temp_df.to_csv('./data/max_temperatures.csv', index_label='Index')
